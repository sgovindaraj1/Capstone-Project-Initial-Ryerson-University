# %% [markdown]
# # Importing datasets

# %%
import pandas as pd
covid=pd.read_csv('C:\\Users\\drgsr\\Desktop\\CAPSTONE\\owid-covid-data.csv')

# %% [markdown]
# # data exploration & cleaning

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16174 entries, 0 to 16173
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   iso_code                  16110 non-null  object
#  1   location                  16174 non-null  object
#  2   date                      16174 non-null  object
#  3   total_cases               16174 non-null  int64
#  4   new_cases                 16174 non-null  int64
#  5   total_deaths              16174 non-null  int64
#  6   new_deaths                16174 non-null  int64
#  7   total_cases_per_million   15871 non-null  float64
#  8   new_cases_per_million     15871 non-null  float64
#  9   total_deaths_per_million  15871 non-null  float64
#  10  new_deaths_per_million    15871 non-null  float64
#  11  total_tests               4061 non-null   float64
#  12  new_tests                 3638 non-null   float64
#  13  total_tests_per_thousand  4061 non-null   float64
#  14  new_tests_per_thousand    3643 non-null   float64
#  15  tests_units               4061 non-null   object
#  16  population                15953 non-null  float64
#  17  population_density        15504 non-null  float64
#  18  median_age                14791 non-null  float64
#  19  aged_65_older             14599 non-null  float64
#  20  aged_70_older             14718 non-null  float64
#  21  gdp_per_capita            14612 non-null  float64
#  22  extreme_poverty           9743 non-null   float64
#  23  cvd_death_rate            14822 non-null  float64
#  24  diabetes_prevalence       15255 non-null  float64
#  25  female_smokers            12262 non-null  float64
#  26  male_smokers              12139 non-null  float64
#  27  handwashing_facilities    6271 non-null   float64
#  28  hospital_beds_per_100k    13789 non-null  float64
# dtypes: float64(21), int64(4), object(4)
# memory usage: 3.6+ MB

# %%
covid.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand', 'tests_units',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty', 'cvd_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
covid.describe()
# Out:
#         total_cases      new_cases   total_deaths    new_deaths  \
# count  1.617400e+04   16174.000000   16174.000000  16174.000000
# mean   1.254933e+04     482.089526     828.141029     33.917398
# std    1.318552e+05    4468.683819    9209.584874    336.346848
# min    0.000000e+00   -2461.000000       0.000000      0.000000
# 25%    2.000000e+00       0.000000       0.000000      0.000000
# 50%    5.100000e+01       2.000000       1.000000      0.000000
# 75%    7.177500e+02      35.000000      13.000000      1.000000
# max    3.898658e+06  101533.000000  274290.000000  10520.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count             15871.000000           15871.000000
# mean                369.042315              12.544942
# std                1209.350998              66.164734
# min                   0.000000            -139.488000
# 25%                   0.169000               0.000000
# 50%                  11.429000               0.148000
# 75%                 170.925000               4.587500
# max               18357.004000            4944.376000
#
#        total_deaths_per_million  new_deaths_per_million   total_tests  \
# count              15871.000000            15871.000000  4.061000e+03
# mean                  15.772244                0.588043  1.593078e+05
# std                   78.552209                3.823383  5.447918e+05
# min                    0.000000                0.000000  1.000000e+00
# 25%                    0.000000                0.000000  5.297000e+03
# 50%                    0.018000                0.000000  2.875000e+04
# 75%                    2.286000                0.029000  1.046060e+05
# max                 1208.085000              200.040000  8.105513e+06
#
#            new_tests  ...  aged_65_older  aged_70_older  gdp_per_capita  \
# count    3638.000000  ...   14599.000000   14718.000000    14612.000000
# mean     7946.874382  ...      10.092819       6.446940    23913.680975
# std     25344.131177  ...       6.519187       4.490884    21582.069416
# min         1.000000  ...       1.144000       0.526000      661.240000
# 25%       428.750000  ...       4.213000       2.385000     7435.047000
# 50%      1551.000000  ...       8.153000       5.060000    16277.671000
# 75%      5245.250000  ...      15.413000      10.129000    36085.843000
# max    318720.000000  ...      27.049000      18.493000   116935.600000
#
#        extreme_poverty  cvd_death_rate  diabetes_prevalence  female_smokers  \
# count      9743.000000    14822.000000         15255.000000    12262.000000
# mean          9.287663      242.269476             8.001287       11.530244
# std          16.773103      119.609650             3.995547       10.604461
# min           0.100000       79.370000             0.990000        0.100000
# 25%           0.500000      140.448000             5.310000        1.900000
# 50%           1.500000      228.467000             7.110000        7.100000
# 75%           7.100000      307.846000            10.080000       20.000000
# max          77.600000      724.417000            23.360000       44.000000
#
#        male_smokers  handwashing_facilities  hospital_beds_per_100k
# count   12139.00000             6271.000000            13789.000000
# mean       32.61154               56.770382                3.280068
# std        13.13365               30.595876                2.639836
# min         7.70000                1.188000                0.100000
# 25%        21.40000               25.383000                1.400000
# 50%        31.40000               60.130000                2.600000
# 75%        40.70000               85.198000                4.280000
# max        78.10000               98.999000               13.800000
#
# [8 rows x 25 columns]

# %%
#Obtain the country specific average so as to compare different country parameters(has removed non-numeric iso code,date,test,tests_units)
covid=covid.groupby('location').mean()
covid.columns
# Out:
# Index(['total_cases', 'new_cases', 'total_deaths', 'new_deaths',
#        'total_cases_per_million', 'new_cases_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million', 'total_tests',
#        'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty', 'cvd_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
#For Outcome of interest of number of cases & death we have used we have used proportional measures which are more meaningful such as Cases per million & Deaths per million and removed other absolute measures of the same,and also removed absolute measures of testing, dates and iso code column
covid.drop(['total_tests_per_thousand','total_cases','new_cases','total_deaths','new_deaths','new_cases_per_million','new_deaths_per_million','total_tests','new_tests','new_tests_per_thousand','population'],axis=1,inplace=True)
covid
# Out:
#                 total_cases_per_million  total_deaths_per_million  \
# location
# Afghanistan                   11.088017                  0.340545
# Albania                      136.663565                  6.002500
# Algeria                       20.313000                  2.398087
# Andorra                     6343.173035                299.039211
# Angola                         0.575592                  0.051041
# ...                                 ...                       ...
# Western Sahara                10.045000                  0.000000
# World                         99.521198                  6.571740
# Yemen                          0.198100                  0.034667
# Zambia                         3.169538                  0.094096
# Zimbabwe                       1.255620                  0.165440
#
#                 population_density  median_age  aged_65_older  aged_70_older  \
# location
# Afghanistan                 54.422        18.6          2.581          1.337
# Albania                    104.871        38.0         13.188          8.643
# Algeria                     17.348        29.1          6.211          3.857
# Andorra                    163.755         NaN            NaN            NaN
# Angola                      23.890        16.8          2.405          1.362
# ...                            ...         ...            ...            ...
# Western Sahara                 NaN        28.4            NaN          1.380
# World                       58.045        30.9          8.696          5.355
# Yemen                       53.508        20.3          2.922          1.583
# Zambia                      22.995        17.7          2.480          1.542
# Zimbabwe                    42.729        19.6          2.822          1.882
#
#                 gdp_per_capita  extreme_poverty  cvd_death_rate  \
# location
# Afghanistan           1803.987              NaN         597.029
# Albania              11803.431              1.1         304.195
# Algeria              13913.839              0.5         278.364
# Andorra                    NaN              NaN         109.135
# Angola                5819.495              NaN         276.045
# ...                        ...              ...             ...
# Western Sahara             NaN              NaN             NaN
# World                15469.207             10.0         233.070
# Yemen                 1479.147             18.8         495.003
# Zambia                3689.251             57.5         234.499
# Zimbabwe              1899.775             21.4         307.846
#
#                 diabetes_prevalence  female_smokers  male_smokers  \
# location
# Afghanistan                    9.59             NaN           NaN
# Albania                       10.08           7.100        51.200
# Algeria                        6.73           0.700        30.400
# Andorra                        7.97          29.000        37.800
# Angola                         3.94             NaN           NaN
# ...                             ...             ...           ...
# Western Sahara                  NaN             NaN           NaN
# World                          8.51           6.434        34.635
# Yemen                          5.35           7.600        29.200
# Zambia                         3.94           3.100        24.700
# Zimbabwe                       1.82           1.600        30.700
#
#                 handwashing_facilities  hospital_beds_per_100k
# location
# Afghanistan                     37.746                   0.500
# Albania                            NaN                   2.890
# Algeria                         83.741                   1.900
# Andorra                            NaN                     NaN
# Angola                          26.664                     NaN
# ...                                ...                     ...
# Western Sahara                     NaN                     NaN
# World                           60.130                   2.705
# Yemen                           49.542                   0.700
# Zambia                          13.938                   2.000
# Zimbabwe                        36.791                   1.700
#
# [211 rows x 14 columns]

# %%
covid.columns
# Out:
# Index(['total_cases_per_million', 'total_deaths_per_million',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cvd_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
index=covid.index
print (index)
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vatican', 'Venezuela', 'Vietnam',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='location', length=211)

# %% [markdown]
# # missing values using KNN imputation

# %%
covid.isnull().sum()
# Out:
# total_cases_per_million       4
# total_deaths_per_million      4
# population_density           13
# median_age                   25
# aged_65_older                28
# aged_70_older                26
# gdp_per_capita               29
# extreme_poverty              91
# cvd_death_rate               26
# diabetes_prevalence          18
# female_smokers               71
# male_smokers                 73
# handwashing_facilities      120
# hospital_beds_per_100k       46
# dtype: int64

# %%
import numpy as np
import pandas as pd
import scipy as sp
from sklearn.impute import KNNImputer

# %%
covid = pd.DataFrame(covid)

# %%
imputer = KNNImputer(n_neighbors=2)

# %%
covid_filled = imputer.fit_transform(covid)

# %%
covid_filled
# Out:
# array([[1.10880165e+01, 3.40545455e-01, 5.44220000e+01, ...,
#         2.99500000e+01, 3.77460000e+01, 5.00000000e-01],
#        [1.36663565e+02, 6.00250000e+00, 1.04871000e+02, ...,
#         5.12000000e+01, 9.11810000e+01, 2.89000000e+00],
#        [2.03130000e+01, 2.39808730e+00, 1.73480000e+01, ...,
#         3.04000000e+01, 8.37410000e+01, 1.90000000e+00],
#        ...,
#        [1.98100000e-01, 3.46666667e-02, 5.35080000e+01, ...,
#         2.92000000e+01, 4.95420000e+01, 7.00000000e-01],
#        [3.16953846e+00, 9.40961538e-02, 2.29950000e+01, ...,
#         2.47000000e+01, 1.39380000e+01, 2.00000000e+00],
#        [1.25562000e+00, 1.65440000e-01, 4.27290000e+01, ...,
#         3.07000000e+01, 3.67910000e+01, 1.70000000e+00]])

# %%
covid_filled = pd.DataFrame(covid_filled)

# %%
covid_filled.head()
# Out:
#              0           1        2     3        4       5           6      7  \
# 0    11.088017    0.340545   54.422  18.6   2.5810  1.3370   1803.9870  28.35
# 1   136.663565    6.002500  104.871  38.0  13.1880  8.6430  11803.4310   1.10
# 2    20.313000    2.398087   17.348  29.1   6.2110  3.8570  13913.8390   0.50
# 3  6343.173035  299.039211  163.755  38.5  14.3715  9.5245  75569.7175   0.20
# 4     0.575592    0.051041   23.890  16.8   2.4050  1.3620   5819.4950   4.20
#
#          8      9    10     11      12     13
# 0  597.029   9.59   4.6  29.95  37.746  0.500
# 1  304.195  10.08   7.1  51.20  91.181  2.890
# 2  278.364   6.73   0.7  30.40  83.741  1.900
# 3  109.135   7.97  29.0  37.80  92.349  4.155
# 4  276.045   3.94  11.7  44.25  26.664  1.200

# %%
covid_filled.columns=['total_cases_per_million', 'total_deaths_per_million',
       'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
       'gdp_per_capita', 'extreme_poverty', 'cvd_death_rate',
       'diabetes_prevalence', 'female_smokers', 'male_smokers',
       'handwashing_facilities', 'hospital_beds_per_100k']

# %%
covid_filled.head()
# Out:
#    total_cases_per_million  total_deaths_per_million  population_density  \
# 0                11.088017                  0.340545              54.422
# 1               136.663565                  6.002500             104.871
# 2                20.313000                  2.398087              17.348
# 3              6343.173035                299.039211             163.755
# 4                 0.575592                  0.051041              23.890
#
#    median_age  aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 0        18.6         2.5810         1.3370       1803.9870            28.35
# 1        38.0        13.1880         8.6430      11803.4310             1.10
# 2        29.1         6.2110         3.8570      13913.8390             0.50
# 3        38.5        14.3715         9.5245      75569.7175             0.20
# 4        16.8         2.4050         1.3620       5819.4950             4.20
#
#    cvd_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0         597.029                 9.59             4.6         29.95
# 1         304.195                10.08             7.1         51.20
# 2         278.364                 6.73             0.7         30.40
# 3         109.135                 7.97            29.0         37.80
# 4         276.045                 3.94            11.7         44.25
#
#    handwashing_facilities  hospital_beds_per_100k
# 0                  37.746                   0.500
# 1                  91.181                   2.890
# 2                  83.741                   1.900
# 3                  92.349                   4.155
# 4                  26.664                   1.200

# %%
covid_filled.shape
# Out:
# (211, 14)

# %%
covid_filled.isnull().sum()
# Out:
# total_cases_per_million     0
# total_deaths_per_million    0
# population_density          0
# median_age                  0
# aged_65_older               0
# aged_70_older               0
# gdp_per_capita              0
# extreme_poverty             0
# cvd_death_rate              0
# diabetes_prevalence         0
# female_smokers              0
# male_smokers                0
# handwashing_facilities      0
# hospital_beds_per_100k      0
# dtype: int64

# %% [markdown]
# # treatment of outliers

# %%
df = pd.DataFrame(np.random.randn(100, 3))

from scipy import stats

df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
# Out:
#            0         1         2
# 0  -1.352729 -0.260561 -0.386629
# 1  -0.650683  1.192592  0.112491
# 2   1.497202 -2.337078  0.167942
# 3  -0.123027  0.313766 -1.949805
# 4  -0.537090 -0.485328 -0.008280
# ..       ...       ...       ...
# 95 -0.544849 -0.263988 -1.398264
# 96  0.915976  0.635907  0.901782
# 97 -0.622054 -1.132908  1.809926
# 98 -0.343076 -0.762163 -0.936990
# 99 -1.628862 -3.119103 -0.537147
#
# [100 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
import scipy as sp
#covid_filled = pd.DataFrame(covid_filled)
#z_scores=scipy.stats.zscore(covid_filled)
z_scores = stats.zscore(covid_filled)
#calculate z-scores of `covid_filled`

abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
new_covid_filled = covid_filled[filtered_entries]

print(new_covid_filled)
# Out:
#      total_cases_per_million  total_deaths_per_million  population_density  \
# 1                 136.663565                  6.002500            104.8710
# 2                  20.313000                  2.398087             17.3480
# 4                   0.575592                  0.051041             23.8900
# 5                 189.368477                  0.000000            165.3475
# 6                 173.196510                 15.818000            231.8450
# ..                       ...                       ...                 ...
# 206                10.045000                  0.000000             73.8525
# 207                99.521198                  6.571740             58.0450
# 208                 0.198100                  0.034667             53.5080
# 209                 3.169538                  0.094096             22.9950
# 210                 1.255620                  0.165440             42.7290
#
#      median_age  aged_65_older  aged_70_older  gdp_per_capita  \
# 1         38.00         13.188          8.643       11803.431
# 2         29.10          6.211          3.857       13913.839
# 4         16.80          2.405          1.362        5819.495
# 5         35.55          6.645          3.499       37601.952
# 6         32.10          6.933          4.631       21490.943
# ..          ...            ...            ...             ...
# 206       28.40          4.675          1.380       11514.795
# 207       30.90          8.696          5.355       15469.207
# 208       20.30          2.922          1.583        1479.147
# 209       17.70          2.480          1.542        3689.251
# 210       19.60          2.822          1.882        1899.775
#
#      extreme_poverty  cvd_death_rate  diabetes_prevalence  female_smokers  \
# 1               1.10        304.1950                10.08           7.100
# 2               0.50        278.3640                 6.73           0.700
# 4               4.20        276.0450                 3.94          11.700
# 5               1.15        179.8055                13.73           2.950
# 6               1.15        191.5110                13.17           9.750
# ..               ...             ...                  ...             ...
# 206             3.10        401.4535                 5.57           4.150
# 207            10.00        233.0700                 8.51           6.434
# 208            18.80        495.0030                 5.35           7.600
# 209            57.50        234.4990                 3.94           3.100
# 210            21.40        307.8460                 1.82           1.600
#
#      male_smokers  handwashing_facilities  hospital_beds_per_100k
# 1          51.200                  91.181                   2.890
# 2          30.400                  83.741                   1.900
# 4          44.250                  26.664                   1.200
# 5          38.850                  91.256                   2.900
# 6          31.600                  77.898                   3.800
# ..            ...                     ...                     ...
# 206        61.300                  67.692                   4.020
# 207        34.635                  60.130                   2.705
# 208        29.200                  49.542                   0.700
# 209        24.700                  13.938                   2.000
# 210        30.700                  36.791                   1.700
#
# [183 rows x 14 columns]

# %% [markdown]
# # visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
sns.pairplot(new_covid_filled)
new_covid_filled
# Out:
#      total_cases_per_million  total_deaths_per_million  population_density  \
# 1                 136.663565                  6.002500            104.8710
# 2                  20.313000                  2.398087             17.3480
# 4                   0.575592                  0.051041             23.8900
# 5                 189.368477                  0.000000            165.3475
# 6                 173.196510                 15.818000            231.8450
# ..                       ...                       ...                 ...
# 206                10.045000                  0.000000             73.8525
# 207                99.521198                  6.571740             58.0450
# 208                 0.198100                  0.034667             53.5080
# 209                 3.169538                  0.094096             22.9950
# 210                 1.255620                  0.165440             42.7290
#
#      median_age  aged_65_older  aged_70_older  gdp_per_capita  \
# 1         38.00         13.188          8.643       11803.431
# 2         29.10          6.211          3.857       13913.839
# 4         16.80          2.405          1.362        5819.495
# 5         35.55          6.645          3.499       37601.952
# 6         32.10          6.933          4.631       21490.943
# ..          ...            ...            ...             ...
# 206       28.40          4.675          1.380       11514.795
# 207       30.90          8.696          5.355       15469.207
# 208       20.30          2.922          1.583        1479.147
# 209       17.70          2.480          1.542        3689.251
# 210       19.60          2.822          1.882        1899.775
#
#      extreme_poverty  cvd_death_rate  diabetes_prevalence  female_smokers  \
# 1               1.10        304.1950                10.08           7.100
# 2               0.50        278.3640                 6.73           0.700
# 4               4.20        276.0450                 3.94          11.700
# 5               1.15        179.8055                13.73           2.950
# 6               1.15        191.5110                13.17           9.750
# ..               ...             ...                  ...             ...
# 206             3.10        401.4535                 5.57           4.150
# 207            10.00        233.0700                 8.51           6.434
# 208            18.80        495.0030                 5.35           7.600
# 209            57.50        234.4990                 3.94           3.100
# 210            21.40        307.8460                 1.82           1.600
#
#      male_smokers  handwashing_facilities  hospital_beds_per_100k
# 1          51.200                  91.181                   2.890
# 2          30.400                  83.741                   1.900
# 4          44.250                  26.664                   1.200
# 5          38.850                  91.256                   2.900
# 6          31.600                  77.898                   3.800
# ..            ...                     ...                     ...
# 206        61.300                  67.692                   4.020
# 207        34.635                  60.130                   2.705
# 208        29.200                  49.542                   0.700
# 209        24.700                  13.938                   2.000
# 210        30.700                  36.791                   1.700
#
# [183 rows x 14 columns]

# %% [markdown]
# # correlations between attributes

# %%
new_covid_filled.corr()
# Out:
#                           total_cases_per_million  total_deaths_per_million  \
# total_cases_per_million                  1.000000                  0.596560
# total_deaths_per_million                 0.596560                  1.000000
# population_density                       0.213070                  0.027152
# median_age                               0.459550                  0.432758
# aged_65_older                            0.478886                  0.499102
# aged_70_older                            0.482372                  0.517054
# gdp_per_capita                           0.690495                  0.462357
# extreme_poverty                         -0.287029                 -0.221540
# cvd_death_rate                          -0.404221                 -0.374804
# diabetes_prevalence                     -0.027174                 -0.080858
# female_smokers                           0.373014                  0.389205
# male_smokers                            -0.178124                 -0.131523
# handwashing_facilities                   0.205374                  0.062097
# hospital_beds_per_100k                   0.208077                  0.181041
#
#                           population_density  median_age  aged_65_older  \
# total_cases_per_million             0.213070    0.459550       0.478886
# total_deaths_per_million            0.027152    0.432758       0.499102
# population_density                  1.000000    0.154430       0.084416
# median_age                          0.154430    1.000000       0.920017
# aged_65_older                       0.084416    0.920017       1.000000
# aged_70_older                       0.067153    0.905251       0.991864
# gdp_per_capita                      0.193116    0.675944       0.588993
# extreme_poverty                    -0.114719   -0.683411      -0.520249
# cvd_death_rate                     -0.208223   -0.314401      -0.330486
# diabetes_prevalence                 0.151623    0.203486      -0.012822
# female_smokers                     -0.024224    0.663806       0.755557
# male_smokers                        0.028709    0.149872       0.043082
# handwashing_facilities              0.231854    0.410850       0.220300
# hospital_beds_per_100k              0.130606    0.696922       0.663584
#
#                           aged_70_older  gdp_per_capita  extreme_poverty  \
# total_cases_per_million        0.482372        0.690495        -0.287029
# total_deaths_per_million       0.517054        0.462357        -0.221540
# population_density             0.067153        0.193116        -0.114719
# median_age                     0.905251        0.675944        -0.683411
# aged_65_older                  0.991864        0.588993        -0.520249
# aged_70_older                  1.000000        0.578264        -0.505877
# gdp_per_capita                 0.578264        1.000000        -0.519248
# extreme_poverty               -0.505877       -0.519248         1.000000
# cvd_death_rate                -0.337191       -0.483496         0.235787
# diabetes_prevalence           -0.046620        0.213225        -0.367509
# female_smokers                 0.750955        0.456501        -0.378342
# male_smokers                   0.041744       -0.122051        -0.234446
# handwashing_facilities         0.192987        0.242907        -0.568590
# hospital_beds_per_100k         0.654650        0.374573        -0.477709
#
#                           cvd_death_rate  diabetes_prevalence  female_smokers  \
# total_cases_per_million        -0.404221            -0.027174        0.373014
# total_deaths_per_million       -0.374804            -0.080858        0.389205
# population_density             -0.208223             0.151623       -0.024224
# median_age                     -0.314401             0.203486        0.663806
# aged_65_older                  -0.330486            -0.012822        0.755557
# aged_70_older                  -0.337191            -0.046620        0.750955
# gdp_per_capita                 -0.483496             0.213225        0.456501
# extreme_poverty                 0.235787            -0.367509       -0.378342
# cvd_death_rate                  1.000000             0.034364       -0.205406
# diabetes_prevalence             0.034364             1.000000        0.015482
# female_smokers                 -0.205406             0.015482        1.000000
# male_smokers                    0.385272             0.210180        0.217421
# handwashing_facilities         -0.113138             0.365016        0.081044
# hospital_beds_per_100k          0.040798             0.034102        0.550198
#
#                           male_smokers  handwashing_facilities  \
# total_cases_per_million      -0.178124                0.205374
# total_deaths_per_million     -0.131523                0.062097
# population_density            0.028709                0.231854
# median_age                    0.149872                0.410850
# aged_65_older                 0.043082                0.220300
# aged_70_older                 0.041744                0.192987
# gdp_per_capita               -0.122051                0.242907
# extreme_poverty              -0.234446               -0.568590
# cvd_death_rate                0.385272               -0.113138
# diabetes_prevalence           0.210180                0.365016
# female_smokers                0.217421                0.081044
# male_smokers                  1.000000                0.207549
# handwashing_facilities        0.207549                1.000000
# hospital_beds_per_100k        0.259224                0.246213
#
#                           hospital_beds_per_100k
# total_cases_per_million                 0.208077
# total_deaths_per_million                0.181041
# population_density                      0.130606
# median_age                              0.696922
# aged_65_older                           0.663584
# aged_70_older                           0.654650
# gdp_per_capita                          0.374573
# extreme_poverty                        -0.477709
# cvd_death_rate                          0.040798
# diabetes_prevalence                     0.034102
# female_smokers                          0.550198
# male_smokers                            0.259224
# handwashing_facilities                  0.246213
# hospital_beds_per_100k                  1.000000

# %%
# pearson's correlation feature selection for numeric input and numeric output
from sklearn.datasets import make_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
# generate dataset
X, y = make_regression(n_samples=100, n_features=100, n_informative=10)
# define feature selection
fs = SelectKBest(score_func=f_regression, k=10)
# apply feature selection
X_selected = fs.fit_transform(X, y)
print(X_selected.shape)
# Out:
# (100, 10)

# %%
# Making use of Pearson Correlation for Feature selection
plt.figure(figsize=(12,10))
cor = new_covid_filled.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# # identification of key attributes

# %%
# Total deaths per million Correlation 
cor_target = abs(cor["total_deaths_per_million"])
# Feature selection
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# total_cases_per_million     0.596560
# total_deaths_per_million    1.000000
# aged_70_older               0.517054
# Name: total_deaths_per_million, dtype: float64

# %% [markdown]
# # building model

# %%
y=new_covid_filled['total_deaths_per_million']

# %%
y
# Out:
# 1       6.002500
# 2       2.398087
# 4       0.051041
# 5       0.000000
# 6      15.818000
#          ...
# 206     0.000000
# 207     6.571740
# 208     0.034667
# 209     0.094096
# 210     0.165440
# Name: total_deaths_per_million, Length: 183, dtype: float64

# %%
X= new_covid_filled [['total_cases_per_million','aged_70_older']]

# %%
X
# Out:
#      total_cases_per_million  aged_70_older
# 1                 136.663565          8.643
# 2                  20.313000          3.857
# 4                   0.575592          1.362
# 5                 189.368477          3.499
# 6                 173.196510          4.631
# ..                       ...            ...
# 206                10.045000          1.380
# 207                99.521198          5.355
# 208                 0.198100          1.583
# 209                 3.169538          1.542
# 210                 1.255620          1.882
#
# [183 rows x 2 columns]

# %%
#test-train split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#      total_cases_per_million  aged_70_older
# 145                15.349333          2.780
# 160                63.209750          6.405
# 179                 3.635702          2.034
# 201               118.969518         10.361
# 180                15.508569          4.229
# ..                       ...            ...
# 8                 172.175615          7.571
# 131                51.771607          4.209
# 135                 0.443441          3.212
# 154               361.229163          9.829
# 63                  0.608965          2.063
#
# [146 rows x 2 columns]

# %%
#linear regression
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression(fit_intercept=True)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict=regression.predict(X_test)

# %%
y_predict
# Out:
# array([43.01612458, -0.12614587, -3.34803077, 20.06063529, 21.3970271 ,
#         4.11899957, 18.02610624, -1.97986606,  0.21184124, -0.20327458,
#        -3.19444326, 11.02605072, -1.64650565,  0.80777753,  4.83739287,
#        25.31199148, -1.76353883, -2.17651502, -0.08797664, -2.19042656,
#        -2.94703176, -3.28082441, 46.40798013, 18.44816038, -2.93861947,
#        13.17619247, 11.0193494 , -2.72699879, -3.41352611, -0.1712452 ,
#        -2.69459297, 27.66692905,  3.19365988, 11.36926177, -3.20766423,
#        36.40443174, -2.42104728])

# %%
y_test
# Out:
# 177    128.565523
# 139      0.270058
# 4        0.051041
# 50      13.119814
# 109      2.625969
# 5        0.000000
# 147     19.152656
# 181      0.384821
# 70       0.843228
# 90       0.151585
# 141      0.054333
# 194     19.090261
# 186      0.489333
# 149      0.755780
# 207      6.571740
# 198     78.957321
# 146      0.284516
# 134      0.000000
# 86       3.351193
# 148      0.000000
# 31       1.120121
# 168      0.385692
# 113     15.295583
# 114      3.775754
# 140      0.681580
# 16      11.818264
# 92      12.705327
# 158      0.000000
# 195      0.000000
# 66       0.000000
# 123      0.142054
# 95      43.124101
# 192      1.810952
# 157      1.126366
# 71       0.367132
# 183     37.845924
# 20       0.065481
# Name: total_deaths_per_million, dtype: float64

# %%
#comparng test & predict
plt.scatter(y_test,y_predict)
plt.ylabel("Predicted")
plt.xlabel("Actual")
plt.title("Multiple Linear Regression Modelling")
# Out:
# Text(0.5, 1.0, 'Multiple Linear Regression Modelling')

# %%
k=2
n=len(X_test)

# %%
n
# Out:
# 37

# %%
#evaluation & performance measures
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from math import sqrt
RMSE=float(format(np.sqrt(mean_squared_error(y_test,y_predict)),'.2f'))
MAE=mean_absolute_error(y_test,y_predict)
MSE=mean_squared_error(y_test,y_predict)
r2=r2_score(y_test,y_predict)
adj_r2=1-(1-r2)*(n-1)/(n-k-1)
MAPE=np.mean(np.abs(y_test-y_predict)/y_test)*100

# %%
print('RMSE=',RMSE,'\nMSE=',MSE,'\nMAE=',MAE,'\nr2=',r2,'\nadj_r2=',adj_r2,'\nMAPE=',MAPE)
# Out:
# RMSE= 18.28
# MSE= 334.2384455520291
# MAE= 8.278494315287183
# r2= 0.46568172281321074
# adj_r2= 0.43425123591987025
# MAPE= inf

# %%
#to add model 2 for comparison (polynomial regression)
